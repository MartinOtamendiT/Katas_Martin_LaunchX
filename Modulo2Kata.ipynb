# %% [markdown]
# # Crear un paquete
#
# En este ejercicio, aprenderás a utilizar entornos virtuales como una forma para no afectar a los paquetes instalados globalmente u otros programas que se ejecutan en tu máquina.

# %% [markdown]
# ## Crear un entorno virtual

# %%
#Código usado para mostrar imágenes en este Notebook, debido a que solo se muestran con Markdown localmente.
from IPython.display import Image
Image("Extra Resources/CreacionVenv.png")

# %% [markdown]
# ## Instalar una biblioteca

# %%
Image("Extra Resources/InstalarBiblioteca.png")

# %% [markdown]
# ## Desactivar un entorno virtual

# %%
Image("Extra Resources/DesactivacionVenv.png")
